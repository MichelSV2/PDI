# %%
import pandas as pd

# %%
datos = pd.read_csv('argentina.csv')

# %%
df = pd.read_csv('argentina.csv')

# %%
Mas_pobreza = df.sort_values(by='poverty',ascending=False)
Menos_pobreza = df.sort_values(by='poverty')

per_cap_positivo = df.sort_values(by='doctors_per_cap', ascending=False)
per_cap_negativo = df.sort_values(by='doctors_per_cap')

grupo = df[df.province == ("Cordoba", "Formosa", "San Luis", "Santa Cruz", "Salta")]

# %%
Mas_pobreza.head()

# %%
Menos_pobreza.head()

# %%
per_cap_positivo.head(1)

# %%
per_cap_negativo.head(1)

# %%
grupo
# Out:
# Empty DataFrame
# Columns: [province, gdp, illiteracy, poverty, deficient_infra, school_dropout, no_healthcare, birth_mortal, pop, movie_theatres_per_cap, doctors_per_cap]
# Index: []
